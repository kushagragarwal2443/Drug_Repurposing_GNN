# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("../data/Guney2016.tsv", sep="\t")
df1 = df1.drop(["Unnamed: 0"], axis=1)
df1.head()
# Out:
#                      Disease      1         2         3       4        5  \
# 0            kidney diseases  79663    5310.0    4306.0   760.0  81494.0
# 1  congenital hypothyroidism   7080  389434.0  169792.0  7253.0   1482.0
# 2        sarcoma, small cell   2130       NaN       NaN     NaN      NaN
# 3   mucopolysaccharidosis vi    411       NaN       NaN     NaN      NaN
# 4    pseudohypoaldosteronism   4306    1729.0   65266.0  6337.0  65125.0
#
#         6        7        8         9  ...  1013  1014  1015  1016  1017  \
# 0  6557.0   5190.0   7225.0    6519.0  ...   NaN   NaN   NaN   NaN   NaN
# 1  7038.0   6528.0  50506.0  405753.0  ...   NaN   NaN   NaN   NaN   NaN
# 2     NaN      NaN      NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN
# 3     NaN      NaN      NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN
# 4  6338.0  10312.0      NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#    1018  1019  1020  1021  1022
# 0   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 1023 columns]

# %%
df2 = pd.read_csv("../data/mesh_disease.csv")
df2.head()
# Out:
#    Unnamed: 0  X CATEGORY   MESHID        MESHTERM     QUALIFIER QUALIFIERID  \
# 0           1  1        C  D000006  abdomen, acute       history     Q000266
# 1           2  2        C  D000006  abdomen, acute  epidemiology     Q000453
# 2           3  3        C  D000006  abdomen, acute    congenital     Q000151
# 3           4  4        C  D000006  abdomen, acute       nursing     Q000451
# 4           5  5        C  D000006  abdomen, acute    immunology     Q000276
#
#          SYNONYM
# 0  Acute Abdomen
# 1  Acute Abdomen
# 2  Acute Abdomen
# 3  Acute Abdomen
# 4  Acute Abdomen

# %%
result_df2 = df2.drop_duplicates(subset=['MESHID', 'MESHTERM'], keep='first')
# result_df2 = result_df2.rename(index = list(range(4528)))
# result_df2["X"] = range(1,4529)
result_df2 = result_df2.drop(["Unnamed: 0"], axis=1)
result_df2.head()
# Out:
#        X CATEGORY   MESHID                  MESHTERM             QUALIFIER  \
# 0      1        C  D000006            abdomen, acute               history
# 105  106        C  D000007        abdominal injuries            immunology
# 210  211        C  D000008       abdominal neoplasms       physiopathology
# 327  328        C  D000012      abetalipoproteinemia  prevention & control
# 803  804        C  D000013  congenital abnormalities        rehabilitation
#
#     QUALIFIERID                              SYNONYM
# 0       Q000266                        Acute Abdomen
# 105     Q000276                    Injury, Abdominal
# 210     Q000503                  Neoplasm, Abdominal
# 327     Q000517  Disease, Betalipoprotein Deficiency
# 803     Q000534                         Birth Defect

# %%
print(len(df2), len(result_df2))
# Out:
# 1657927 4528

# %%
meshidterm = {}

for i in result_df2["X"]:
    key = result_df2["MESHID"][i-1]
    value = result_df2["MESHTERM"][i-1]
    meshidterm[key] = value

print(meshidterm)
# Out:
# {'D000006': 'abdomen, acute', 'D000007': 'abdominal injuries', 'D000008': 'abdominal neoplasms', 'D000012': 'abetalipoproteinemia', 'D000013': 'congenital abnormalities', 'D000014': 'abnormalities, drug-induced', 'D000015': 'abnormalities, multiple', 'D000016': 'abnormalities, radiation-induced', 'D000022': 'abortion, spontaneous', 'D000026': 'abortion, habitual', 'D000027': 'abortion, incomplete', 'D000030': 'abortion, missed', 'D000031': 'abortion, septic', 'D000033': 'abortion, threatened', 'D000034': 'abortion, veterinary', 'D000037': 'abruptio placentae', 'D000038': 'abscess', 'D000039': 'peritonsillar abscess', 'D000051': 'acantholysis', 'D000052': 'acanthosis nigricans', 'D000126': 'achlorhydria', 'D000130': 'achondroplasia', 'D000137': 'acid-base imbalance', 'D000138': 'acidosis', 'D000140': 'acidosis, lactic', 'D000141': 'acidosis, renal tubular', 'D000142': 'acidosis, respiratory', 'D000151': 'acinetobacter infections', 'D000152': 'acne vulgaris', 'D000153': 'acne keloid', 'D000160': 'vestibulocochlear nerve diseases', 'D000163': 'acquired immunodeficiency syndrome', 'D000168': 'acrocephalosyndactylia', 'D000169': 'acrodermatitis', 'D000170': 'acrodynia', 'D000172': 'acromegaly', 'D000182': 'acth syndrome, ectopic', 'D000187': 'actinobacillosis', 'D000189': 'actinobacillus infections', 'D000193': 'actinomycetales infections', 'D000196': 'actinomycosis', 'D000208': 'acute disease', 'D000210': 'acute-phase reaction', 'D000219': 'adams-stokes syndrome', 'D000224': 'addison disease', 'D000230': 'adenocarcinoma', 'D000231': 'adenocarcinoma, papillary', 'D000232': 'adenofibroma', 'D000235': 'adenolymphoma', 'D000236': 'adenoma', 'D000237': 'adenoma, basophil', 'D000238': 'adenoma, chromophobe', 'D000239': 'adenoma, acidophil', 'D000257': 'adenoviridae infections', 'D000258': 'adenovirus infections, human', 'D000267': 'tissue adhesions', 'D000270': 'adie syndrome', 'D000274': 'adiposis dolorosa', 'D000291': 'adnexal diseases', 'D000292': 'pelvic inflammatory disease', 'D000303': 'adrenal cortex diseases', 'D000306': 'adrenal cortex neoplasms', 'D000307': 'adrenal gland diseases', 'D000308': 'adrenocortical hyperfunction', 'D000309': 'adrenal insufficiency', 'D000310': 'adrenal gland neoplasms', 'D000312': 'adrenal hyperplasia, congenital', 'D000314': 'adrenal rest tumor', 'D000326': 'adrenoleukodystrophy', 'D000334': 'aerophagy', 'D000343': 'afferent loop syndrome', 'D000347': 'afibrinogenemia', 'D000355': 'african horse sickness', 'D000357': 'african swine fever', 'D000361': 'agammaglobulinemia', 'D000370': 'ageusia', 'D000377': 'agnosia', 'D000380': 'agranulocytosis', 'D000381': 'agraphia', 'D000382': "agricultural workers' diseases", 'D000386': 'aids-related complex', 'D000387': 'ainhum', 'D000402': 'airway obstruction', 'D000405': 'akinetic mutism', 'D000419': 'albuminuria', 'D000425': 'alcohol amnestic disorder', 'D000430': 'alcohol withdrawal delirium', 'D000435': 'alcoholic intoxication', 'D000437': 'alcoholism', 'D000453': 'aleutian mink disease', 'D000471': 'alkalosis', 'D000472': 'alkalosis, respiratory', 'D000474': 'alkaptonuria', 'D000505': 'alopecia', 'D000506': 'alopecia areata', 'D000507': 'mucinosis, follicular', 'D000532': 'altitude sickness', 'D000542': 'alveolitis, extrinsic allergic', 'D000544': 'alzheimer disease', 'D000550': 'amblyopia', 'D000562': 'amebiasis', 'D000564': 'ameloblastoma', 'D000567': 'amelogenesis imperfecta', 'D000568': 'amenorrhea', 'D000592': 'amino acid metabolism, inborn errors', 'D000608': 'renal aminoacidurias', 'D000647': 'amnesia', 'D000648': 'amnesia, retrograde', 'D000652': 'amniotic band syndrome', 'D000673': 'amputation, traumatic', 'D000686': 'amyloidosis', 'D000690': 'amyotrophic lateral sclerosis', 'D000694': 'anal gland neoplasms', 'D000699': 'pain insensitivity, congenital', 'D000707': 'anaphylaxis', 'D000708': 'anaplasia', 'D000711': 'anaplasmataceae infections', 'D000712': 'anaplasmosis', 'D000724': 'ancylostomiasis', 'D000740': 'anemia', 'D000741': 'anemia, aplastic ...

# %%
df3 = pd.read_csv("../data/original_disease_drug.tsv", sep = "\t")
df3.head()
# Out:
#   # Disease(MESH) Chemical
# 0    MESH:D005923  DB00564
# 1    MESH:D009503  DB01072
# 2    MESH:D016115  DB01759
# 3    MESH:D018476  DB00451
# 4    MESH:C567059  DB00641

# %%
print(len(df3))
# Out:
# 466657

# %%
count = 0
notinlist = []

for i in range(len(df3)):
    chemical = df3["Chemical"][i]
    disease = df3["# Disease(MESH)"][i]
    disease = disease[5:]
    if(disease not in meshidterm and disease not in notinlist):
        count+=1
        notinlist.append(disease)

print(count)
# Out:
# 2513

# %%
count = 0
for i in range(len(df1)):
    disease_name = df1["Disease"][i]
    for key in meshidterm:
        if(disease_name == meshidterm[key]):
            count+=1
            break
            
print("Diseases with MESH IDs:", count)
print("Total Diseases:", len(df1))
# Out:
# Diseases with MESH IDs: 1446
# Total Diseases: 1489

# %%
Guney16_preprocessed = pd.merge(result_df2["MESHID"], df1,
                                how='inner', 
                                right_on=df1["Disease"], 
                                left_on=result_df2["MESHTERM"])
Guney16_preprocessed = Guney16_preprocessed.drop(["key_0", "Disease"], axis=1)
Guney16_preprocessed
# Out:
#        MESHID       1       2        3       4       5        6       7  \
# 0     D000012    4547     NaN      NaN     NaN     NaN      NaN     NaN
# 1     D000013  374654  5820.0   9289.0  5824.0  4000.0   5828.0  3854.0
# 2     D000015  374654  1302.0   8626.0  2657.0  5190.0   2138.0  5192.0
# 3     D000052    2261  3643.0      NaN     NaN     NaN      NaN     NaN
# 4     D000130    2261  1280.0      NaN     NaN     NaN      NaN     NaN
# ...       ...     ...     ...      ...     ...     ...      ...     ...
# 1441  D059327    4920  3239.0   8200.0     NaN     NaN      NaN     NaN
# 1442  D059345    4538  2717.0   1282.0  4535.0  1471.0  51128.0  4541.0
# 1443  D059446    7405  4838.0  55997.0  7547.0     NaN      NaN     NaN
# 1444  D061085  374654  2736.0   6496.0  6469.0  3476.0   7050.0  5727.0
# 1445  D061325     675  5892.0   5889.0   672.0     NaN      NaN     NaN
#
#            8       9  ...  1013  1014  1015  1016  1017  1018  1019  1020  \
# 0        NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     3852.0  3853.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     5077.0  5824.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3        NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4        NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...      ...     ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1441     NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1442  4540.0  5654.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1443     NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1444  3897.0  9990.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1445     NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#       1021  1022
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
# ...    ...   ...
# 1441   NaN   NaN
# 1442   NaN   NaN
# 1443   NaN   NaN
# 1444   NaN   NaN
# 1445   NaN   NaN
#
# [1446 rows x 1023 columns]

# %%
#Adding Sars cov row
sars_cov19 = ["D000086382"]

# %%
cov19_df = pd.read_csv("../data/SARSprotein-Humanprotein.csv")
print(cov19_df.shape)
cov19_df.head()
# Out:
# (332, 3)
#          SARS  EntrezID  Symbol
# 0  sars-cov2e      8546   AP3B1
# 1  sars-cov2e     23476    BRD4
# 2  sars-cov2e      6046    BRD2
# 3  sars-cov2e     10283   CWC27
# 4  sars-cov2e    124245  ZC3H18

# %%
len(set(target_proteins))
# Out:
# 332

# %%
target_proteins = list(cov19_df["EntrezID"])
target_proteins
# Out:
# [8546,
#  23476,
#  6046,
#  10283,
#  124245,
#  57153,
#  9512,
#  10897,
#  481,
#  34,
#  2108,
#  2040,
#  2677,
#  523,
#  5714,
#  7905,
#  23203,
#  196527,
#  10531,
#  10463,
#  60493,
#  148867,
#  10426,
#  79934,
#  113174,
#  92840,
#  92105,
#  89874,
#  10844,
#  80222,
#  57142,
#  51439,
#  10157,
#  26993,
#  25980,
#  28969,
#  9136,
#  26986,
#  1459,
#  1460,
#  10146,
#  8761,
#  23367,
#  25940,
#  79753,
#  5976,
#  4343,
#  9908,
#  9188,
#  55131,
#  25873,
#  51125,
#  25921,
#  5422,
#  5557,
#  5558,
#  23649,
#  79709,
#  5318,
#  161,
#  2671,
#  57222,
#  1173,
#  80273,
#  6902,
#  55206,
#  10295,
#  10270,
#  23077,
#  10569,
#  8737,
#  9898,
#  219743,
#  51248,
#  84726,
#  55833,
#  24149,
#  64784,
#  159195,
#  29066,
#  23185,
#  55285,
#  6938,
#  53938,
#  54477,
#  9755,
#  11113,
#  3281,
#  5116,
#  11116,
#  5576,
#  5566,
#  5577,
#  5962,
#  1063,
#  7088,
#  7090,
#  166,
#  2802,
#  2801,
#  2804,
#  56850,
#  9857,
#  9659,
#  9662,
#  23177,
#  11064,
#  23085,
#  9648,
#  79745,
#  51199,
#  201134,
#  145282,
#  8975,
#  79571,
#  152789,
#  55755,
#  10142,
#  64689,
#  79443,
#  79078,
#  11190,
#  29110,
#  51361,
#  22981,
#  2717,
#  3615,
#  23408,
#  10204,
#  382,
#  10193,
#  11001,
#  9470,
#  5447,
#  5910,
#  23325,
#  23307,
#  26058,
#  3416,
#  26519,
#  440138,
#  23225,
#  90580,
#  55735,
#  26515,
#  26520,
#  3066,
#  2876,
#  55621,
#  10632,
#  537,
#  10280,
#  79572,
#  8540,
#  80777,
#  2181,
#  1727,
#  5898,
#  1312,
#  5878,
#  7879,
#  4218,
#  5862,
#  10890,
#  51552,
#  387,
#  5861,
#  2782,
#  2787,
#  10960,
#  7841,
#  26092,
#  64757,
#  169714,
#  9653,
#  91942,
#  51097,
#  949,
#  57106,
#  79877,
#  26355,
#  131118,
#  55829,
#  80142,
#  22931,
#  10199,
#  6731,
#  11101,
#  7468,
#  6728,
#  6729,
#  64432,
#  1662,
#  51574,
#  56257,
#  25983,
#  11340,
#  79731,
#  79954,
#  79080,
#  51091,
#  56915,
#  51010,
#  26574,
#  25831,
#  51116,
#  64969,
#  23404,
#  23107,
#  2963,
#  2200,
#  2201,
#  8021,
#  23636,
#  10238,
#  7458,
#  53371,
#  57534,
#  23111,
#  91754,
#  84858,
#  4927,
#  9818,
#  27430,
#  10516,
#  5538,
#  8453,
#  55700,
#  79178,
#  79699,
#  26521,
#  9978,
#  6921,
#  6923,
#  3162,
#  286827,
#  151188,
#  23339,
#  23155,
#  55823,
#  25777,
#  29880,
#  30968,
#  4928,
#  8480,
#  23787,
#  55027,
#  23195,
#  5352,
#  1861,
#  8614,
#  5327,
#  3688,
#  284106,
#  1291,
#  5817,
#  1786,
#  4015,
#  5046,
#  83729,
#  10577,
#  4240,
#  10956,
#  4884,
#  79070,
#  143888,
#  56605,
#  23646,
#  80020,
#  79586,
#  126789,
#  23065,
#  8836,
#  27248,
#  23765,
#  55768,
#  90161,
#  6388,
#  4758,
#  9518,
#  80213,
#  23071,
#  80267,
#  64374,
#  23509,
#  64093,
#  79666,
#  54850,
#  55757,
#  54480,
#  9510,
#  10525,
#  51661,
#  8754,
#  60681,
#  9368,
#  27243,
#  7812,
#  9868,
#  4140,
#  2011,
#  51611,
#  79077,
#  4139,
#  58155,
#  9529,
#  7993,
#  8733,
#  7466,
#  4363,
#  2150,
#  22937,
#  23333,
#  27346,
#  55676,
#  202018,
#  79956,
#  79671,
#  162427,
#  84720,
#  55711,
#  51295,
#  79053,
#  55116,
#  27069,
#  28976,
#  54602,
#  617,
#  51103,
#  50999,
#  4715,
#  94005]

# %%
sars_cov19 = sars_cov19 + target_proteins + [np.nan]*690
len(sars_cov19)
# Out:
# 1023

# %%
temp = pd.Series(sars_cov19, index = Guney16_preprocessed.columns)
Guney16_preprocessed = Guney16_preprocessed.append(temp, ignore_index=True)

# %%
Guney16_preprocessed.to_csv("../data/Guney16_preprocessed.csv")

# %%
df3 = pd.read_csv("../data/drug-gene.csv")
df3 = df3.drop(["Unnamed: 0"], axis=1)
print(df3.shape)
df3.head()
# Out:
# (24648, 13)
#       type       ID       Name   State  Approved  \
# 0  biotech  DB00001  Lepirudin  liquid  approved
# 1  biotech  DB00002  Cetuximab  liquid  approved
# 2  biotech  DB00002  Cetuximab  liquid  approved
# 3  biotech  DB00002  Cetuximab  liquid  approved
# 4  biotech  DB00002  Cetuximab  liquid  approved
#
#                                           Indication Gene_Target      DB_id  \
# 0  For the treatment of heparin-induced thrombocy...          F2  BE0000048
# 1  Cetuximab, used in combination with irinotecan...        EGFR  BE0002100
# 2  Cetuximab, used in combination with irinotecan...      FCGR3B  BE0002100
# 3  Cetuximab, used in combination with irinotecan...         C1R  BE0002100
# 4  Cetuximab, used in combination with irinotecan...        C1QA  BE0002100
#
#                                                 name organism         Type  \
# 0                                        Prothrombin   Humans  Polypeptide
# 1  Low affinity immunoglobulin gamma Fc region re...   Humans  Polypeptide
# 2  Low affinity immunoglobulin gamma Fc region re...   Humans  Polypeptide
# 3  Low affinity immunoglobulin gamma Fc region re...   Humans  Polypeptide
# 4  Low affinity immunoglobulin gamma Fc region re...   Humans  Polypeptide
#
#    entrez_id ATC_code
# 0     2147.0  B01AE02
# 1     1956.0  L01XC06
# 2     2215.0  L01XC06
# 3      715.0  L01XC06
# 4      712.0  L01XC06

# %%
df3 = df3[["ID", "entrez_id"]]
print(df3.shape)
df3.head()
# Out:
# (24648, 2)
#         ID  entrez_id
# 0  DB00001     2147.0
# 1  DB00002     1956.0
# 2  DB00002     2215.0
# 3  DB00002      715.0
# 4  DB00002      712.0

# %%
df3.to_csv("../data/drug-gene.csv")

# %%
df4 = pd.read_csv("../data/PPI.csv")
print(df4.shape)
df4.head()
# Out:
# (327924, 3)
#    proteinA_entrezid  proteinB_entrezid  \
# 0               9796              56992
# 1               7918               9240
# 2               8233              23548
# 3               4899              11253
# 4               5297               8601
#
#                                           databases
# 0                                    bioplex|HIPPIE
# 1  instruct|hiunion|APID|biogrid|HINT-binary|intact
# 2                                    bioplex|HIPPIE
# 3                                            encode
# 4                                           bioplex

# %%
df4 = df4[["proteinA_entrezid", "proteinB_entrezid"]]
df4.rename(columns = {"proteinA_entrezid": "gene1", "proteinB_entrezid": "gene2"}, inplace = True)
print(df4.shape)
df4.head()
# Out:
# (327924, 2)
#    gene1  gene2
# 0   9796  56992
# 1   7918   9240
# 2   8233  23548
# 3   4899  11253
# 4   5297   8601

# %%
df4.to_csv("../data/ppi_preprocessed.csv")
